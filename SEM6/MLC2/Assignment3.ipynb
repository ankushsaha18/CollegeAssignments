# %% [markdown]
# ## Assignment 3 Lab Question

# %%
# 1. Write a program to save a trained machine learning model using joblib.dump()

from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
import joblib

iris = load_iris()

X = iris.data
y = iris.target

model = RandomForestClassifier()
model.fit(X, y)

joblib.dump(model, "iris_model.pkl")
print("Model Saved Successfully")
# Out:
# Model Saved Successfully

# %%
# 2. Write a Python program to load a saved model using joblib.load() and make predictions.

import joblib

model = joblib.load("iris_model.pkl")

sample = [[5.1, 3.5, 1.4, 0.2]]
prediction = model.predict(sample)[0]
print("Prediction:", iris.target_names[prediction])
# Out:
# Prediction: setosa

# %%
# 3. Write a Tkinter program to create a GUI window with the title "Iris Flower Classification"

from tkinter import *

window = Tk()
window.title("Iris Flower Classification")
window.geometry("400x300")
window.mainloop()

# %%
# 4. Write a Tkinter program to create labels and entry boxes for Sepal Length and Sepal Width

from tkinter import *

window = Tk()

Label(window, text="Sepal Length").grid(row=0, column=0)

entry1 = Entry(window)
entry1.grid(row=0, column=1)

Label(window, text="Sepal Width").grid(row=1, column=0)

entry2 = Entry(window)
entry2.grid(row=1, column=1)

window.mainloop()

# %%
# 5. Write a Python program to create a button in Tkinter that displays a popup message when clicked

from tkinter import *
from tkinter import messagebox

def show_message():
    messagebox.showinfo("Message", "Button Clicked")

window = Tk()
Button(window, text="Click", command=show_message).pack()
window.mainloop()

# %%
# 6. Write a Python code snippet to handle invalid numeric input using try-except ValueError

try:
    value = float(input("Enter Number: "))
    print(value)

except ValueError:
    print("Invalid Numeric Input")
# Out:
# Invalid Numeric Input

# %%
# 7. Write a program to check whether the file iris_model.pkl exists using the os module

import os

if os.path.exists("iris_model.pkl"):
    print("File Exists")

else:
    print("File Not Found")
# Out:
# File Exists

# %%
# 8. Write a Python program to create four input fields using Tkinter Entry widgets

from tkinter import *

window = Tk()

e1 = Entry(window)
e1.pack()

e2 = Entry(window)
e2.pack()

e3 = Entry(window)
e3.pack()

e4 = Entry(window)
e4.pack()

window.mainloop()

# %%
# 9. Write code to predict the flower category using model.predict() for user-entered values

import joblib

model = joblib.load("iris_model.pkl")
data = [[5.1, 3.5, 1.4, 0.2]]

prediction = model.predict(data)
print(prediction)
# Out:
# [0]

# %%
# 10. Write a Python program to display the predicted flower name using messagebox.showinfo()

from tkinter import messagebox

flower = "Setosa"
messagebox.showinfo("Prediction", flower)
# Out:
# 'ok'

# %%
# 11. Write a program to create a fixed-size Tkinter window using geometry() and resizable()

from tkinter import *

window = Tk()
window.geometry("400x300")
window.resizable(False, False)

window.mainloop()
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Write a Python program that loads the Iris dataset and prints the target names (setosa, versicolor, virginica).

from sklearn.datasets import load_iris

iris = load_iris()
print(iris.target_names)
# Out:
# ['setosa' 'versicolor' 'virginica']
